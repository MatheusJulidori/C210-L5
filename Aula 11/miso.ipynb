# %% [markdown]
# # Lógica Fuzzy

# %% [markdown]
# * Grau de pertinência: o quanto um elemento 'x' pertence a um conjunto 'A'
# * Variável: rótulo associado a uma variável linguística
# * Conjunto de termos: nomes dados aos valores de cada variável
# * Universo de discurso: domínio em que cada variável é definida

# %% [markdown]
# ![1](imagens/img1.jpg)

# %% [markdown]
# ## Funcionamento de um sistema fuzzy

# %% [markdown]
# ![1](imagens/img4.jpg)

# %% [markdown]
# ## Problema da gorjeta

# %% [markdown]
# ![1](imagens/img2.jpg)

# %%
#!pip install scikit-fuzzy

import numpy as np
import skfuzzy as fuzzy
import skfuzzy.control as control
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/matheusjulidori/Documents/Projects/C210-L5/Aula 11/miso.ipynb Cell 8 line 5
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X35sZmlsZQ%3D%3D?line=3'>4</a> import skfuzzy as fuzzy
# ----> <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> import skfuzzy.control as control
#
# File ~/.local/lib/python3.10/site-packages/skfuzzy/control/__init__.py:15
#       1 """
#       2 skfuzzy.control subpackage, providing a high-level API for fuzzy system design.
#       3
#       4 """
#       6 __all__ = ['Antecedent',
#       7            'Consequent',
#       8            'ControlSystem',
#    (...)
#      12            'accumulation_mult',
#      13            ]
# ---> 15 from .antecedent_consequent import (Antecedent, Consequent,
#      16                                     accumulation_max, accumulation_mult)
#      17 from .controlsystem import ControlSystem, ControlSystemSimulation
#      18 from .rule import Rule
#
# File ~/.local/lib/python3.10/site-packages/skfuzzy/control/antecedent_consequent.py:8
#       5 import networkx as nx
#       7 from .state import StatefulProperty
# ----> 8 from .fuzzyvariable import FuzzyVariable
#      11 def accumulation_max(*args):
#      12     """
#      13     Take the maximum of input values/arrays.
#      14
#      15     This is the default OR aggregation method for a fuzzy Rule.
#      16     """
#
# File ~/.local/lib/python3.10/site-packages/skfuzzy/control/fuzzyvariable.py:7
#       4 import numpy as np
#       6 from ..membership import trimf
# ----> 7 from .visualization import FuzzyVariableVisualizer
#       8 from .term import Term
#      10 try:
#
# File ~/.local/lib/python3.10/site-packages/skfuzzy/control/visualization.py:8
#       6 import numpy as np
#       7 import networkx as nx
# ----> 8 import matplotlib.pyplot as plt
#      10 from ..fuzzymath.fuzzy_ops import interp_membership
#      13 class FuzzyVariableVisualizer(object):
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:952
#     945     return config
#     948 # When constructing the global instances, we need to perform certain updates
#     949 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     950 # triggering resolution of _auto_backend_sentinel.
#     951 rcParamsDefault = _rc_params_in_file(
# --> 952     cbook._get_data_path("matplotlibrc"),
#     953     # Strip leading comment.
#     954     transform=lambda line: line[1:] if line.startswith("#") else line,
#     955     fail_on_error=True)
#     956 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
#     957 # Normally, the default matplotlibrc file contains *no* entry for backend (the
#     958 # corresponding line starts with ##, not #; we fill on _auto_backend_sentinel
#     959 # in that case.  However, packagers can set a different default backend
#     960 # (resulting in a normal `#backend: foo` line) in which case we should *not*
#     961 # fill in _auto_backend_sentinel.
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:561, in _get_data_path(*args)
#     555 def _get_data_path(*args):
#     556     """
#     557     Return the `pathlib.Path` to a resource file provided by Matplotlib.
#     558
#     559     ``*args`` specify a path relative to the base data path.
#     560     """
# --> 561     return Path(matplotlib.get_data_path(), *args)
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %% [markdown]
# ## Criando o Antescendent (Entrada de dados)

# %%
# Definindo universo de discurso e nome da variável
universo = np.arange(0, 11)

qualidade = control.Antecedent(universe = universo, label = "qualidade")
servico = control.Antecedent(universe = universo, label = "servico")

# Criando função de pertinência triangular -> trimf, trapezoidal -> trapmf
qualidade["ruim"] = fuzzy.trapmf(qualidade.universe, [0, 0, 2, 5])
qualidade["bom"] = fuzzy.trimf(qualidade.universe, [3, 5, 7])
qualidade["excelente"] = fuzzy.trapmf(qualidade.universe, [5, 8, 10, 10])

servico["ruim"] = fuzzy.trapmf(servico.universe, [0, 0, 2, 5])
servico["bom"] = fuzzy.trimf(servico.universe, [3, 5, 7])
servico["excelente"] = fuzzy.trapmf(servico.universe, [5, 8, 10, 10])

qualidade.view()
servico.view()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/matheusjulidori/Documents/Projects/C210-L5/Aula 11/miso.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # Definindo universo de discurso e nome da variável
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> universo = np.arange(0, 11)
# ----> <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> qualidade = control.Antecedent(universe = universo, label = "qualidade")
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X32sZmlsZQ%3D%3D?line=4'>5</a> servico = control.Antecedent(universe = universo, label = "servico")
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> # Criando função de pertinência triangular -> trimf, trapezoidal -> trapmf
#
# NameError: name 'control' is not defined

# %% [markdown]
# ## Criando consequent (Saída de dados)

# %%
# Universo da gorjeta
universo_gorjeta = np.arange(0, 21)

gorjeta = control.Consequent(universe = universo_gorjeta, label = "gorjeta")

gorjeta["pequena"] = fuzzy.trapmf(gorjeta.universe, [0, 0, 5, 8])
gorjeta["razoável"] = fuzzy.trimf(gorjeta.universe, [5, 10, 15])
gorjeta["generosa"] = fuzzy.trapmf(gorjeta.universe, [10, 15, 20, 20])

gorjeta.view()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/matheusjulidori/Documents/Projects/C210-L5/Aula 11/miso.ipynb Cell 12 line 4
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> # Universo da gorjeta
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> universo_gorjeta = np.arange(0, 21)
# ----> <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> gorjeta = control.Consequent(universe = universo_gorjeta, label = "gorjeta")
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> gorjeta["pequena"] = fuzzy.trapmf(gorjeta.universe, [0, 0, 5, 8])
#       <a href='vscode-notebook-cell:/home/matheusjulidori/Documents/Projects/C210-L5/Aula%2011/miso.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> gorjeta["razoável"] = fuzzy.trimf(gorjeta.universe, [5, 10, 15])
#
# NameError: name 'control' is not defined

# %% [markdown]
# ## Conjunto de Regras

# %% [markdown]
# ![1](imagens/img3.jpg)

# %%
regra1 = control.Rule(servico["ruim"] | qualidade["ruim"], gorjeta["pequena"])
regra2 = control.Rule(servico["bom"], gorjeta["razoável"])
regra3 = control.Rule(servico["excelente"] | qualidade["excelente"], gorjeta["generosa"])

# Adicionando regras ao controle
gorjeta_controle = control.ControlSystem([regra1, regra2, regra3])

# %% [markdown]
# ## Criando o sistema

# %%
# Criando sistema com o controle de gorjeta
sistema = control.ControlSystemSimulation(gorjeta_controle)

sistema.input["qualidade"] = 5
sistema.input["servico"] = 4

# Executando o sistema
sistema.compute()

print(f"Resultado 'desfuzzificado': {sistema.output['gorjeta']}")

gorjeta.view(sim = sistema)
# Out:
# Resultado 'desfuzzificado': 7.584062196307095
